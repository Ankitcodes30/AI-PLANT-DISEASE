# %% [markdown]
# # Epic 2: Model Building
# ## Building MobileNetV2 with Transfer Learning

# %%
import sys
sys.path.append('../src')

from model import create_model
from tensorflow.keras.utils import plot_model

# %%
# Create model
model = create_model(num_classes=38)
model.summary()

# %%
# Visualize model architecture
plot_model(model, to_file='../results/plots/model_architecture.png', show_shapes=True)
